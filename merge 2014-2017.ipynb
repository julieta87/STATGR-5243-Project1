# %%
import pandas as pd
from datetime import time
from sklearn.impute import KNNImputer
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import ace_tools_open as tools
import os

# %%
df_2014_01 = pd.read_csv('yellow_tripdata_2014-01.csv')
df_2014_02 = pd.read_csv('yellow_tripdata_2014-02.csv')
df_2014_03 = pd.read_csv('yellow_tripdata_2014-03.csv')
df_2014_04 = pd.read_csv('yellow_tripdata_2014-04.csv')
df_2014_05 = pd.read_csv('yellow_tripdata_2014-05.csv')
df_2014_06 = pd.read_csv('yellow_tripdata_2014-06.csv')
df_2014_07 = pd.read_csv('yellow_tripdata_2014-07.csv')
df_2014_08 = pd.read_csv('yellow_tripdata_2014-08.csv')
df_2014_09 = pd.read_csv('yellow_tripdata_2014-09.csv')
df_2014_10 = pd.read_csv('yellow_tripdata_2014-10.csv')
df_2014_11 = pd.read_csv('yellow_tripdata_2014-11.csv')
df_2014_12 = pd.read_csv('yellow_tripdata_2014-12.csv')

# %%
df_2015_01 = pd.read_csv('yellow_tripdata_2015-01.csv')
df_2015_02 = pd.read_csv('yellow_tripdata_2015-02.csv')
df_2015_03 = pd.read_csv('yellow_tripdata_2015-03.csv')
df_2015_04 = pd.read_csv('yellow_tripdata_2015-04.csv')
df_2015_05 = pd.read_csv('yellow_tripdata_2015-05.csv')
df_2015_06 = pd.read_csv('yellow_tripdata_2015-06.csv')
df_2015_07 = pd.read_csv('yellow_tripdata_2015-07.csv')
df_2015_08 = pd.read_csv('yellow_tripdata_2015-08.csv')
df_2015_09 = pd.read_csv('yellow_tripdata_2015-09.csv')
df_2015_10 = pd.read_csv('yellow_tripdata_2015-10.csv')
df_2015_11 = pd.read_csv('yellow_tripdata_2015-11.csv')
df_2015_12 = pd.read_csv('yellow_tripdata_2015-12.csv')

# %%
df_2016_01 = pd.read_csv('yellow_tripdata_2016-01.csv')
df_2016_02 = pd.read_csv('yellow_tripdata_2016-02.csv')
df_2016_03 = pd.read_csv('yellow_tripdata_2016-03.csv')
df_2016_04 = pd.read_csv('yellow_tripdata_2016-04.csv')
df_2016_05 = pd.read_csv('yellow_tripdata_2016-05.csv')
df_2016_06 = pd.read_csv('yellow_tripdata_2016-06.csv')
df_2016_07 = pd.read_csv('yellow_tripdata_2016-07.csv')
df_2016_08 = pd.read_csv('yellow_tripdata_2016-08.csv')
df_2016_09 = pd.read_csv('yellow_tripdata_2016-09.csv')
df_2016_10 = pd.read_csv('yellow_tripdata_2016-10.csv')
df_2016_11 = pd.read_csv('yellow_tripdata_2016-11.csv')
df_2016_12 = pd.read_csv('yellow_tripdata_2016-12.csv')

# %%
df_2017_01 = pd.read_csv('yellow_tripdata_2017-01.csv')
df_2017_02 = pd.read_csv('yellow_tripdata_2017-02.csv')
df_2017_03 = pd.read_csv('yellow_tripdata_2017-03.csv')
df_2017_04 = pd.read_csv('yellow_tripdata_2017-04.csv')
df_2017_05 = pd.read_csv('yellow_tripdata_2017-05.csv')
df_2017_06 = pd.read_csv('yellow_tripdata_2017-06.csv')
df_2017_07 = pd.read_csv('yellow_tripdata_2017-07.csv')
df_2017_08 = pd.read_csv('yellow_tripdata_2017-08.csv')
df_2017_09 = pd.read_csv('yellow_tripdata_2017-09.csv')
df_2017_10 = pd.read_csv('yellow_tripdata_2017-10.csv')
df_2017_11 = pd.read_csv('yellow_tripdata_2017-11.csv')
df_2017_12 = pd.read_csv('yellow_tripdata_2017-12.csv')

# %%
df_2014 = [df_2014_01, df_2014_02, df_2014_03, df_2014_04, df_2014_05, df_2014_06,
       df_2014_07, df_2014_08, df_2014_09, df_2014_10, df_2014_11, df_2014_12]

df_2014 = pd.concat(df_2014, ignore_index=True)
print(df_2014.head())
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2014-01-01 00:02:00   2014-01-01 00:04:00                6
# 1         2  2014-01-01 00:06:00   2014-01-01 00:09:00                5
# 2         2  2014-01-01 00:10:00   2014-01-01 00:13:00                5
# 3         2  2014-01-01 00:54:00   2014-01-01 00:55:00                5
# 4         1  2014-01-01 00:29:18   2014-01-01 00:35:13                2
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0            0.0           1                NaN           146           146
# 1            0.0           1                NaN           146           146
# 2            0.0           1                NaN           146           146
# 3            0.0           1                NaN           264           264
# 4            1.8           1                  N           229           262
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0             1          3.5    0.5      0.5        0.02           0.0
# 1             1          3.5    0.5      0.5        0.05           0.0
# 2             1          3.5    0.5      0.5        0.08           0.0
# 3             2          2.5    0.5      0.5        0.00           0.0
# 4             2          7.5    0.5      0.5        0.00           0.0
#
#    improvement_surcharge  total_amount  congestion_surcharge  airport_fee
# 0                    0.0          4.52                   NaN          NaN
# 1                    0.0          4.55                   NaN          NaN
# 2                    0.0          4.58                   NaN          NaN
# 3                    0.0          3.50                   NaN          NaN
# 4                    0.0          8.50                   NaN          NaN

# %%
df_2015 = [df_2015_01, df_2015_02, df_2015_03, df_2015_04, df_2015_05, df_2015_06,
       df_2015_07, df_2015_08, df_2015_09, df_2015_10, df_2015_11, df_2015_12]

df_2015 = pd.concat(df_2015, ignore_index=True)
print(df_2015.head())
# Out:
#    Unnamed: 0  VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 0           0         1  2015-01-01 00:11:33   2015-01-01 00:16:48
# 1           1         1  2015-01-01 00:18:24   2015-01-01 00:24:20
# 2           2         1  2015-01-01 00:26:19   2015-01-01 00:41:06
# 3           3         1  2015-01-01 00:45:26   2015-01-01 00:53:20
# 4           4         1  2015-01-01 00:59:21   2015-01-01 01:05:24
#
#    passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# 0                1            1.0           1                  N
# 1                1            0.9           1                  N
# 2                1            3.5           1                  N
# 3                1            2.1           1                  N
# 4                1            1.0           1                  N
#
#    PULocationID  DOLocationID  payment_type  fare_amount  extra  mta_tax  \
# 0            41           166             1          5.7    0.5      0.5
# 1           166           238             3          6.0    0.5      0.5
# 2           238           162             1         13.2    0.5      0.5
# 3           162           263             1          8.2    0.5      0.5
# 4           236           141             3          6.0    0.5      0.5
#
#    tip_amount  tolls_amount  improvement_surcharge  total_amount  \
# 0        1.40           0.0                    0.0          8.40
# 1        0.00           0.0                    0.0          7.30
# 2        2.90           0.0                    0.0         17.40
# 3        2.37           0.0                    0.0         11.87
# 4        0.00           0.0                    0.0          7.30
#
#    congestion_surcharge  airport_fee
# 0                   NaN          NaN
# 1                   NaN          NaN
# 2                   NaN          NaN
# 3                   NaN          NaN
# 4                   NaN          NaN

# %%
df_2016 = [df_2016_01, df_2016_02, df_2016_03, df_2016_04, df_2016_05, df_2016_06,
       df_2016_07, df_2016_08, df_2016_09, df_2016_10, df_2016_11, df_2016_12]

df_2016 = pd.concat(df_2016, ignore_index=True)
print(df_2016.head())
# Out:
#    Unnamed: 0  VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 0           0         1  2016-01-01 00:12:22   2016-01-01 00:29:14
# 1           1         1  2016-01-01 00:41:31   2016-01-01 00:55:10
# 2           2         1  2016-01-01 00:53:37   2016-01-01 00:59:57
# 3           3         1  2016-01-01 00:13:28   2016-01-01 00:18:07
# 4           4         1  2016-01-01 00:33:04   2016-01-01 00:47:14
#
#    passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# 0                1            3.2           1                  N
# 1                2            1.0           1                  N
# 2                1            0.9           1                  N
# 3                1            0.8           1                  N
# 4                1            1.8           1                  N
#
#    PULocationID  DOLocationID  payment_type  fare_amount  extra  mta_tax  \
# 0            48           262             1         14.0    0.5      0.5
# 1           162            48             2          9.5    0.5      0.5
# 2           246            90             2          6.0    0.5      0.5
# 3           170           162             2          5.0    0.5      0.5
# 4           161           140             2         11.0    0.5      0.5
#
#    tip_amount  tolls_amount  improvement_surcharge  total_amount  \
# 0        3.06           0.0                    0.3         18.36
# 1        0.00           0.0                    0.3         10.80
# 2        0.00           0.0                    0.3          7.30
# 3        0.00           0.0                    0.3          6.30
# 4        0.00           0.0                    0.3         12.30
#
#    congestion_surcharge  airport_fee
# 0                   NaN          NaN
# 1                   NaN          NaN
# 2                   NaN          NaN
# 3                   NaN          NaN
# 4                   NaN          NaN

# %%
df_2017 = [df_2017_01, df_2017_02, df_2017_03, df_2017_04, df_2017_05, df_2017_06,
       df_2017_07, df_2017_08, df_2017_09, df_2017_10, df_2017_11, df_2017_12]

df_2017 = pd.concat(df_2017, ignore_index=True)
print(df_2017.head())
# Out:
#    Unnamed: 0  VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 0           0         1  2017-01-01 00:32:05   2017-01-01 00:37:48
# 1           1         1  2017-01-01 00:43:25   2017-01-01 00:47:42
# 2           2         1  2017-01-01 00:49:10   2017-01-01 00:53:53
# 3           3         1  2017-01-01 00:36:42   2017-01-01 00:41:09
# 4           4         1  2017-01-01 00:07:41   2017-01-01 00:18:16
#
#    passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# 0                1            1.2           1                  N
# 1                2            0.7           1                  N
# 2                2            0.8           1                  N
# 3                1            1.1           1                  N
# 4                1            3.0           1                  N
#
#    PULocationID  DOLocationID  payment_type  fare_amount  extra  mta_tax  \
# 0           140           236             2          6.5    0.5      0.5
# 1           237           140             2          5.0    0.5      0.5
# 2           140           237             2          5.5    0.5      0.5
# 3            41            42             2          6.0    0.5      0.5
# 4            48           263             2         11.0    0.5      0.5
#
#    tip_amount  tolls_amount  improvement_surcharge  total_amount  \
# 0         0.0           0.0                    0.3           7.8
# 1         0.0           0.0                    0.3           6.3
# 2         0.0           0.0                    0.3           6.8
# 3         0.0           0.0                    0.3           7.3
# 4         0.0           0.0                    0.3          12.3
#
#    congestion_surcharge  airport_fee
# 0                   NaN          NaN
# 1                   NaN          NaN
# 2                   NaN          NaN
# 3                   NaN          NaN
# 4                   NaN          NaN

# %%
def preprocess_data(df):
    columns_to_keep = ["tpep_pickup_datetime", "tpep_dropoff_datetime", "passenger_count",
                       "trip_distance", "payment_type", "fare_amount", "tip_amount", "total_amount", "PULocationID", 
                       "DOLocationID"]
    
    df = df[columns_to_keep].copy()
    
    df["tpep_pickup_datetime"] = pd.to_datetime(df["tpep_pickup_datetime"])
    df["tpep_dropoff_datetime"] = pd.to_datetime(df["tpep_dropoff_datetime"])
    
    df = df[(df["fare_amount"] > 0) & (df["trip_distance"] > 0)]

    df["trip_duration"] = (df["tpep_dropoff_datetime"] - df["tpep_pickup_datetime"]).dt.total_seconds() / 60
    
    df = df[(df["trip_duration"] > 1) & (df["trip_duration"] < 300)]
    
    return df

# %%
df_2014_cleaned = preprocess_data(df_2014)
df_2014_cleaned.head()
# Out:
#   tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  trip_distance  \
# 4  2014-01-01 00:29:18   2014-01-01 00:35:13                2            1.8
# 5  2014-01-01 00:36:33   2014-01-01 00:55:19                3            4.8
# 6  2014-01-01 00:20:43   2014-01-01 00:31:07                2            2.0
# 7  2014-01-01 00:48:52   2014-01-01 00:56:14                1            1.1
# 8  2014-01-01 00:45:29   2014-01-01 00:55:33                1            1.6
#
#    payment_type  fare_amount  tip_amount  total_amount  PULocationID  \
# 4             2          7.5         0.0           8.5           229
# 5             2         17.5         0.0          18.5           140
# 6             2          9.5         0.0          10.5            82
# 7             2          6.5         0.0           7.5           162
# 8             1          8.5         1.0          10.5            90
#
#    DOLocationID  trip_duration
# 4           262       5.916667
# 5             7      18.766667
# 6           226      10.400000
# 7           170       7.366667
# 8            79      10.066667

# %%
df_2015_cleaned = preprocess_data(df_2015)
df_2015_cleaned.head()
# Out:
#   tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  trip_distance  \
# 0  2015-01-01 00:11:33   2015-01-01 00:16:48                1            1.0
# 1  2015-01-01 00:18:24   2015-01-01 00:24:20                1            0.9
# 2  2015-01-01 00:26:19   2015-01-01 00:41:06                1            3.5
# 3  2015-01-01 00:45:26   2015-01-01 00:53:20                1            2.1
# 4  2015-01-01 00:59:21   2015-01-01 01:05:24                1            1.0
#
#    payment_type  fare_amount  tip_amount  total_amount  PULocationID  \
# 0             1          5.7        1.40          8.40            41
# 1             3          6.0        0.00          7.30           166
# 2             1         13.2        2.90         17.40           238
# 3             1          8.2        2.37         11.87           162
# 4             3          6.0        0.00          7.30           236
#
#    DOLocationID  trip_duration
# 0           166       5.250000
# 1           238       5.933333
# 2           162      14.783333
# 3           263       7.900000
# 4           141       6.050000

# %%
df_2016_cleaned = preprocess_data(df_2016)
df_2016_cleaned.head()
# Out:
#   tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  trip_distance  \
# 0  2016-01-01 00:12:22   2016-01-01 00:29:14                1            3.2
# 1  2016-01-01 00:41:31   2016-01-01 00:55:10                2            1.0
# 2  2016-01-01 00:53:37   2016-01-01 00:59:57                1            0.9
# 3  2016-01-01 00:13:28   2016-01-01 00:18:07                1            0.8
# 4  2016-01-01 00:33:04   2016-01-01 00:47:14                1            1.8
#
#    payment_type  fare_amount  tip_amount  total_amount  PULocationID  \
# 0             1         14.0        3.06         18.36            48
# 1             2          9.5        0.00         10.80           162
# 2             2          6.0        0.00          7.30           246
# 3             2          5.0        0.00          6.30           170
# 4             2         11.0        0.00         12.30           161
#
#    DOLocationID  trip_duration
# 0           262      16.866667
# 1            48      13.650000
# 2            90       6.333333
# 3           162       4.650000
# 4           140      14.166667

# %%
df_2017_cleaned = preprocess_data(df_2017)
df_2017_cleaned.head()
# Out:
#   tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  trip_distance  \
# 0  2017-01-01 00:32:05   2017-01-01 00:37:48                1            1.2
# 1  2017-01-01 00:43:25   2017-01-01 00:47:42                2            0.7
# 2  2017-01-01 00:49:10   2017-01-01 00:53:53                2            0.8
# 3  2017-01-01 00:36:42   2017-01-01 00:41:09                1            1.1
# 4  2017-01-01 00:07:41   2017-01-01 00:18:16                1            3.0
#
#    payment_type  fare_amount  tip_amount  total_amount  PULocationID  \
# 0             2          6.5         0.0           7.8           140
# 1             2          5.0         0.0           6.3           237
# 2             2          5.5         0.0           6.8           140
# 3             2          6.0         0.0           7.3            41
# 4             2         11.0         0.0          12.3            48
#
#    DOLocationID  trip_duration
# 0           236       5.716667
# 1           140       4.283333
# 2           237       4.716667
# 3            42       4.450000
# 4           263      10.583333

# %%
df_2014_cleaned['pickup_date'] = df_2014_cleaned['tpep_pickup_datetime'].dt.date

# %%
df_2015_cleaned['pickup_date'] = df_2015_cleaned['tpep_pickup_datetime'].dt.date

# %%
df_2016_cleaned['pickup_date'] = df_2016_cleaned['tpep_pickup_datetime'].dt.date

# %%
df_2017_cleaned['pickup_date'] = df_2017_cleaned['tpep_pickup_datetime'].dt.date

# %%
taxi_data = pd.read_csv("taxi_zone_lookup.csv")

# %%
pickup_df = df_2014_cleaned.merge(taxi_data[['LocationID', 'Borough']], 
                              left_on="PULocationID", right_on="LocationID", 
                              how="left")
pickup_df.rename(columns={"Borough": "Pickup_Borough"}, inplace=True)
pickup_df.drop(columns=["LocationID"], inplace=True)

dropoff_df = df_2014_cleaned.merge(taxi_data[['LocationID', 'Borough']], 
                               left_on="DOLocationID", right_on="LocationID", 
                               how="left")
dropoff_df.rename(columns={"Borough": "Dropoff_Borough"}, inplace=True)
dropoff_df.drop(columns=["LocationID"], inplace=True)

pickup_tallies = pickup_df.groupby(["pickup_date", "Pickup_Borough"]).size().reset_index(name="Count")
pickup_pivot = pickup_tallies.pivot(index="pickup_date", columns="Pickup_Borough", values="Count").fillna(0)
pickup_pivot.columns = [f"{col}_Pickups" for col in pickup_pivot.columns]

dropoff_tallies = dropoff_df.groupby(["pickup_date", "Dropoff_Borough"]).size().reset_index(name="Count")
dropoff_pivot = dropoff_tallies.pivot(index="pickup_date", columns="Dropoff_Borough", values="Count").fillna(0)
dropoff_pivot.columns = [f"{col}_Dropoffs" for col in dropoff_pivot.columns]

final_borough_tallies_2014 = pickup_pivot.join(dropoff_pivot, how="outer").reset_index()

# %%
pickup_df = df_2015_cleaned.merge(taxi_data[['LocationID', 'Borough']], 
                              left_on="PULocationID", right_on="LocationID", 
                              how="left")
pickup_df.rename(columns={"Borough": "Pickup_Borough"}, inplace=True)
pickup_df.drop(columns=["LocationID"], inplace=True)

dropoff_df = df_2015_cleaned.merge(taxi_data[['LocationID', 'Borough']], 
                               left_on="DOLocationID", right_on="LocationID", 
                               how="left")
dropoff_df.rename(columns={"Borough": "Dropoff_Borough"}, inplace=True)
dropoff_df.drop(columns=["LocationID"], inplace=True)

pickup_tallies = pickup_df.groupby(["pickup_date", "Pickup_Borough"]).size().reset_index(name="Count")
pickup_pivot = pickup_tallies.pivot(index="pickup_date", columns="Pickup_Borough", values="Count").fillna(0)
pickup_pivot.columns = [f"{col}_Pickups" for col in pickup_pivot.columns]

dropoff_tallies = dropoff_df.groupby(["pickup_date", "Dropoff_Borough"]).size().reset_index(name="Count")
dropoff_pivot = dropoff_tallies.pivot(index="pickup_date", columns="Dropoff_Borough", values="Count").fillna(0)
dropoff_pivot.columns = [f"{col}_Dropoffs" for col in dropoff_pivot.columns]

final_borough_tallies_2015 = pickup_pivot.join(dropoff_pivot, how="outer").reset_index()

# %%
pickup_df = df_2016_cleaned.merge(taxi_data[['LocationID', 'Borough']], 
                              left_on="PULocationID", right_on="LocationID", 
                              how="left")
pickup_df.rename(columns={"Borough": "Pickup_Borough"}, inplace=True)
pickup_df.drop(columns=["LocationID"], inplace=True)

dropoff_df = df_2016_cleaned.merge(taxi_data[['LocationID', 'Borough']], 
                               left_on="DOLocationID", right_on="LocationID", 
                               how="left")
dropoff_df.rename(columns={"Borough": "Dropoff_Borough"}, inplace=True)
dropoff_df.drop(columns=["LocationID"], inplace=True)

pickup_tallies = pickup_df.groupby(["pickup_date", "Pickup_Borough"]).size().reset_index(name="Count")
pickup_pivot = pickup_tallies.pivot(index="pickup_date", columns="Pickup_Borough", values="Count").fillna(0)
pickup_pivot.columns = [f"{col}_Pickups" for col in pickup_pivot.columns]

dropoff_tallies = dropoff_df.groupby(["pickup_date", "Dropoff_Borough"]).size().reset_index(name="Count")
dropoff_pivot = dropoff_tallies.pivot(index="pickup_date", columns="Dropoff_Borough", values="Count").fillna(0)
dropoff_pivot.columns = [f"{col}_Dropoffs" for col in dropoff_pivot.columns]

final_borough_tallies_2016 = pickup_pivot.join(dropoff_pivot, how="outer").reset_index()

# %%
pickup_df = df_2017_cleaned.merge(taxi_data[['LocationID', 'Borough']], 
                              left_on="PULocationID", right_on="LocationID", 
                              how="left")
pickup_df.rename(columns={"Borough": "Pickup_Borough"}, inplace=True)
pickup_df.drop(columns=["LocationID"], inplace=True)

dropoff_df = df_2017_cleaned.merge(taxi_data[['LocationID', 'Borough']], 
                               left_on="DOLocationID", right_on="LocationID", 
                               how="left")
dropoff_df.rename(columns={"Borough": "Dropoff_Borough"}, inplace=True)
dropoff_df.drop(columns=["LocationID"], inplace=True)

pickup_tallies = pickup_df.groupby(["pickup_date", "Pickup_Borough"]).size().reset_index(name="Count")
pickup_pivot = pickup_tallies.pivot(index="pickup_date", columns="Pickup_Borough", values="Count").fillna(0)
pickup_pivot.columns = [f"{col}_Pickups" for col in pickup_pivot.columns]

dropoff_tallies = dropoff_df.groupby(["pickup_date", "Dropoff_Borough"]).size().reset_index(name="Count")
dropoff_pivot = dropoff_tallies.pivot(index="pickup_date", columns="Dropoff_Borough", values="Count").fillna(0)
dropoff_pivot.columns = [f"{col}_Dropoffs" for col in dropoff_pivot.columns]

final_borough_tallies_2017 = pickup_pivot.join(dropoff_pivot, how="outer").reset_index()

# %%
daily_counts_2014 = df_2014_cleaned.groupby('pickup_date').size().rename("frequency_of_rides")

df_2014_cleaned['fare_per_mile'] = df_2014_cleaned['fare_amount'] / df_2014_cleaned['trip_distance']

daily_agg_2014 = df_2014_cleaned.groupby('pickup_date').agg({
    'fare_amount': ['mean', 'sum'],         # avg fares, total fares
    'trip_duration': 'mean',                # duration (average)
    'trip_distance': 'mean',                # avg trip distance
    'tip_amount': ['mean', 'sum'],          # tip amount average, total tip amount
    'passenger_count': ['mean', 'sum'],      # avg passengers, sum of passengers
    'fare_per_mile': 'mean'                 # avg fare per mile
}).reset_index()

daily_agg_2014.columns = [
    'pickup_date', 
    'avg fares', 
    'total fares', 
    'duration', 
    'avg trip distance', 
    'tip amount avg',
    'total tip amount', 
    'avg passengers', 
    'sum of passengers',
    'avg fare per mile'
]

daily_agg_2014['tip percentage'] = (daily_agg_2014['total tip amount'] / daily_agg_2014['total fares']) * 100

daily_summary_2014 = daily_agg_2014.merge(daily_counts_2014.reset_index(), on='pickup_date')

daily_summary_2014['day of week'] = pd.to_datetime(daily_summary_2014['pickup_date']).dt.day_name()

column_order = [
    'pickup_date',
    'day of week',
    'avg fares',
    'total fares',
    'tip percentage',
    'duration',
    'frequency_of_rides',
    'avg trip distance',
    'tip amount avg',
    'avg passengers',
    'sum of passengers',
    'avg fare per mile'
]

daily_summary_2014 = daily_summary_2014[column_order]

tools.display_dataframe_to_user(name="Daily Summary Taxi Data (2014)", dataframe=daily_summary_2014)
# Out:
# Daily Summary Taxi Data (2014)
# <table id="itables_83eeeebf_aa0f_47b9_a231_6dd79ce58d9e" class="display nowrap" data-quarto-disable-processing="true" style="table-layout:auto;width:auto;margin:auto;caption-side:bottom">
# <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>pickup_date</th>
#       <th>day of week</th>
#       <th>avg fares</th>
#       <th>total fares</th>
#       <th>tip percentage</th>
#       <th>duration</th>
#       <th>frequency_of_rides</th>
#       <th>avg trip distance</th>
#       <th>tip amount avg</th>
#       <th>avg passengers</th>
#       <th>sum of passengers</th>
#       <th>avg fare per mile</th>
#     </tr>
#   </thead><tbody><tr>
# <td style="vertical-align:middle; text-align:left">
# <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
# Loading ITables v2.2.4 from the internet...
# (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
# </tr></tbody>
# </table>
# <link href="https://www.unpkg.com/dt_for_itables@2.0.13/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import {DataTable, jQuery as $} from 'https://www.unpkg.com/dt_for_itables@2.0.13/dt_bundle.js';
#
#     document.querySelectorAll("#itables
696755, 633726, 5.340258], [20, "2014-01-21", "Tuesday", 13.359871, 3369733.58, 12.1946, 17.58941, 252228, 2.552406, 1.629183, 1.651625, 416586, 7.811799], [21, "2014-01-22", "Wednesday", 11.782385, 4406270.16, 12.856588, 12.759058, 373971, 2.748179, 1.514813, 1.678454, 627693, 5.988241], [22, "2014-01-23", "Thursday", 12.9208, 5907118.45, 12.72913, 14.842602, 457179, 2.868346, 1.644705, 1.670626, 763775, 6.423334], [23, "2014-01-24", "Friday", 12.336144, 6216663.97, 12.349188, 13.890774, 503939, 2.736318, 1.523414, 1.695279, 854317, 6.307351], [24, "2014-01-25", "Saturday", 11.16768, 5862953.72, 11.455566, 11.32441, 524993, 2.637313, 1.279321, 1.769696, 929078, 5.644586], [25, "2014-01-26", "Sunday", 11.857833, 5350431.9, 11.796654, 11.124639, 451215, 2.985045, 1.398828, 1.746744, 788157, 5.362878], [26, "2014-01-27", "Monday", 11.859684, 4911367.92, 12.610596, 12.1757, 414123, 2.803997, 1.495577, 1.641186, 679653, 5.877769], [27, "2014-01-28", "Tuesday", 11.674616, 5411733.41, 12.828188, 12.572495, 463547, 2.600726, 1.497642, 1.64881, 764301, 6.242214], [28, "2014-01-29", "Wednesday", 11.938981, 5645681.44, 12.95558, 13.074743, 472878, 2.654927, 1.546764, 1.655416, 782810, 6.290713], [29, "2014-01-30", "Thursday", 12.306911, 6035309.23, 12.895174, 13.606636, 49

# %%
daily_counts_2015 = df_2015_cleaned.groupby('pickup_date').size().rename("frequency_of_rides")

df_2015_cleaned['fare_per_mile'] = df_2015_cleaned['fare_amount'] / df_2015_cleaned['trip_distance']

daily_agg_2015 = df_2015_cleaned.groupby('pickup_date').agg({
    'fare_amount': ['mean', 'sum'],         # avg fares, total fares
    'trip_duration': 'mean',                # duration (average)
    'trip_distance': 'mean',                # avg trip distance
    'tip_amount': ['mean', 'sum'],          # tip amount average, total tip amount
    'passenger_count': ['mean', 'sum'],      # avg passengers, sum of passengers
    'fare_per_mile': 'mean'                 # avg fare per mile
}).reset_index()

daily_agg_2015.columns = [
    'pickup_date', 
    'avg fares', 
    'total fares', 
    'duration', 
    'avg trip distance', 
    'tip amount avg',
    'total tip amount', 
    'avg passengers', 
    'sum of passengers',
    'avg fare per mile'
]

daily_agg_2015['tip percentage'] = (daily_agg_2015['total tip amount'] / daily_agg_2015['total fares']) * 100

daily_summary_2015 = daily_agg_2015.merge(daily_counts_2015.reset_index(), on='pickup_date')

daily_summary_2015['day of week'] = pd.to_datetime(daily_summary_2015['pickup_date']).dt.day_name()

column_order = [
    'pickup_date',
    'day of week',
    'avg fares',
    'total fares',
    'tip percentage',
    'duration',
    'frequency_of_rides',
    'avg trip distance',
    'tip amount avg',
    'avg passengers',
    'sum of passengers',
    'avg fare per mile'
]

daily_summary_2015 = daily_summary_2015[column_order]

tools.display_dataframe_to_user(name="Daily Summary Taxi Data (2015)", dataframe=daily_summary_2015)
# Out:
# Daily Summary Taxi Data (2015)
# <table id="itables_3391f069_5746_44df_adb5_f7c473a0fd23" class="display nowrap" data-quarto-disable-processing="true" style="table-layout:auto;width:auto;margin:auto;caption-side:bottom">
# <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>pickup_date</th>
#       <th>day of week</th>
#       <th>avg fares</th>
#       <th>total fares</th>
#       <th>tip percentage</th>
#       <th>duration</th>
#       <th>frequency_of_rides</th>
#       <th>avg trip distance</th>
#       <th>tip amount avg</th>
#       <th>avg passengers</th>
#       <th>sum of passengers</th>
#       <th>avg fare per mile</th>
#     </tr>
#   </thead><tbody><tr>
# <td style="vertical-align:middle; text-align:left">
# <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
# Loading ITables v2.2.4 from the internet...
# (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
# </tr></tbody>
# </table>
# <link href="https://www.unpkg.com/dt_for_itables@2.0.13/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import {DataTable, jQuery as $} from 'https://www.unpkg.com/dt_for_itables@2.0.13/dt_bundle.js';
#
#     document.querySelectorAll("#itables_
 12.672905, 427370, 11.756511, 1.661874, 1.63427, 698438, 5.874884], [21, "2015-01-22", "Thursday", 12.069317, 5403083.25, 14.149388, 12.968672, 447671, 21.688689, 1.707734, 1.638228, 733387, 5.909385], [22, "2015-01-23", "Friday", 12.132476, 5674067.79, 13.636765, 13.376709, 467676, 64.126686, 1.654477, 1.659189, 775963, 5.969758], [23, "2015-01-24", "Saturday", 11.074227, 5049349.14, 12.811863, 11.387882, 455955, 9.916883, 1.418815, 1.736544, 791786, 5.460361], [24, "2015-01-25", "Sunday", 12.042269, 4852733.44, 13.065522, 11.678326, 402975, 3.028641, 1.573385, 1.705927, 687446, 5.334297], [25, "2015-01-26", "Monday", 11.852275, 2695764.31, 13.088243, 13.328622, 227447, 2.653167, 1.551255, 1.633919, 371630, 6.235044], [26, "2015-01-27", "Tuesday", 9.286438, 1247131.53, 13.38307, 8.559904, 134296, 2.238302, 1.242811, 1.71475, 230284, 5.193691], [27, "2015-01-28", "Wednesday", 12.07948, 4548576.33, 13.809925, 13.261045, 376554, 2.761946, 1.668167, 1.637492, 616604, 6.011711], [28, "2015-01-29", "Thursday", 12.624727, 5400807.81, 13.829988, 14.531339, 427796, 2.775272, 1.745998, 1.634782, 699353, 6.282432], [29, "2015-01-30", "Friday", 12.123908, 5802987.17, 13.559434,

# %%
daily_counts_2016 = df_2016_cleaned.groupby('pickup_date').size().rename("frequency_of_rides")

df_2016_cleaned['fare_per_mile'] = df_2016_cleaned['fare_amount'] / df_2016_cleaned['trip_distance']

daily_agg_2016 = df_2016_cleaned.groupby('pickup_date').agg({
    'fare_amount': ['mean', 'sum'],         # avg fares, total fares
    'trip_duration': 'mean',                # duration (average)
    'trip_distance': 'mean',                # avg trip distance
    'tip_amount': ['mean', 'sum'],          # tip amount average, total tip amount
    'passenger_count': ['mean', 'sum'],      # avg passengers, sum of passengers
    'fare_per_mile': 'mean'                 # avg fare per mile
}).reset_index()

daily_agg_2016.columns = [
    'pickup_date', 
    'avg fares', 
    'total fares', 
    'duration', 
    'avg trip distance', 
    'tip amount avg',
    'total tip amount', 
    'avg passengers', 
    'sum of passengers',
    'avg fare per mile'
]

daily_agg_2016['tip percentage'] = (daily_agg_2016['total tip amount'] / daily_agg_2016['total fares']) * 100

daily_summary_2016 = daily_agg_2016.merge(daily_counts_2016.reset_index(), on='pickup_date')

daily_summary_2016['day of week'] = pd.to_datetime(daily_summary_2016['pickup_date']).dt.day_name()

column_order = [
    'pickup_date',
    'day of week',
    'avg fares',
    'total fares',
    'tip percentage',
    'duration',
    'frequency_of_rides',
    'avg trip distance',
    'tip amount avg',
    'avg passengers',
    'sum of passengers',
    'avg fare per mile'
]

daily_summary_2016 = daily_summary_2016[column_order]

tools.display_dataframe_to_user(name="Daily Summary Taxi Data (2016)", dataframe=daily_summary_2016)
# Out:
# Daily Summary Taxi Data (2016)
# <table id="itables_fed10d16_605e_4aa8_b1cf_3744ecb6406d" class="display nowrap" data-quarto-disable-processing="true" style="table-layout:auto;width:auto;margin:auto;caption-side:bottom">
# <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>pickup_date</th>
#       <th>day of week</th>
#       <th>avg fares</th>
#       <th>total fares</th>
#       <th>tip percentage</th>
#       <th>duration</th>
#       <th>frequency_of_rides</th>
#       <th>avg trip distance</th>
#       <th>tip amount avg</th>
#       <th>avg passengers</th>
#       <th>sum of passengers</th>
#       <th>avg fare per mile</th>
#     </tr>
#   </thead><tbody><tr>
# <td style="vertical-align:middle; text-align:left">
# <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
# Loading ITables v2.2.4 from the internet...
# (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
# </tr></tbody>
# </table>
# <link href="https://www.unpkg.com/dt_for_itables@2.0.13/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import {DataTable, jQuery as $} from 'https://www.unpkg.com/dt_for_itables@2.0.13/dt_bundle.js';
#
#     document.querySelectorAll("#itables_fed10d16_605e_4aa8_b1cf_3744ecb6406d:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         // Define the table data
#         const data = [[0, "
12.168449, 5059190.86, 14.444362, 13.563651, 415763, 2.765529, 1.757655, 1.645055, 683953, 6.097579], [22, "2016-01-23", "Saturday", 11.867804, 912586.62, 14.185192, 13.876874, 76896, 2.803298, 1.683471, 1.691362, 130059, 5.758523], [23, "2016-01-24", "Sunday", 12.163801, 1920676.35, 13.347652, 12.525523, 157901, 2.954935, 1.623582, 1.751072, 276496, 5.765941], [24, "2016-01-25", "Monday", 14.842666, 4133637.99, 14.056576, 17.721356, 278497, 3.321023, 2.086371, 1.647116, 458717, 6.787257], [25, "2016-01-26", "Tuesday", 14.363598, 4656405.55, 14.520713, 17.566123, 324181, 3.061601, 2.085697, 1.638634, 531214, 6.943391], [26, "2016-01-27", "Wednesday", 13.322908, 4738079.15, 14.794371, 15.820392, 355634, 2.86649, 1.97104, 1.633061, 580772, 6.539551], [27, "2016-01-28", "Thursday", 13.084858, 4965651.21, 14.90719, 15.181005, 379496, 15.196847, 1.950585, 1.639938, 622350, 6.293759], [28, "2016-01-29", "Friday", 12.670166, 5189662.05, 14.534512, 14.434484, 409597, 2.817272, 1.841547, 1.651362, 676393, 6.228914], [29, "2016-01-30", "Saturday", 12.180991, 5245061.77, 13.213834, 1

# %%
start_date = pd.to_datetime("2017-01-01").date()
end_date = pd.to_datetime("2017-12-31").date()
df_2017_cleaned = df_2017_cleaned[
    (df_2017_cleaned['pickup_date'] >= start_date) & 
    (df_2017_cleaned['pickup_date'] <= end_date)
]

daily_counts_2017 = df_2017_cleaned.groupby('pickup_date').size().rename("frequency_of_rides")

df_2017_cleaned['fare_per_mile'] = df_2017_cleaned['fare_amount'] / df_2017_cleaned['trip_distance']

daily_agg_2017 = df_2017_cleaned.groupby('pickup_date').agg({
    'fare_amount': ['mean', 'sum'],         # avg fares, total fares
    'trip_duration': 'mean',                # duration (average)
    'trip_distance': 'mean',                # avg trip distance
    'tip_amount': ['mean', 'sum'],          # tip amount average, total tip amount
    'passenger_count': ['mean', 'sum'],      # avg passengers, sum of passengers
    'fare_per_mile': 'mean'                 # avg fare per mile
}).reset_index()

daily_agg_2017.columns = [
    'pickup_date', 
    'avg fares', 
    'total fares', 
    'duration', 
    'avg trip distance', 
    'tip amount avg',
    'total tip amount', 
    'avg passengers', 
    'sum of passengers',
    'avg fare per mile'
]

daily_agg_2017['tip percentage'] = (daily_agg_2017['total tip amount'] / daily_agg_2017['total fares']) * 100

daily_summary_2017 = daily_agg_2017.merge(daily_counts_2017.reset_index(), on='pickup_date')

daily_summary_2017['day of week'] = pd.to_datetime(daily_summary_2017['pickup_date']).dt.day_name()

column_order = [
    'pickup_date',
    'day of week',
    'avg fares',
    'total fares',
    'tip percentage',
    'duration',
    'frequency_of_rides',
    'avg trip distance',
    'tip amount avg',
    'avg passengers',
    'sum of passengers',
    'avg fare per mile'
]

daily_summary_2017 = daily_summary_2017[column_order]

tools.display_dataframe_to_user(name="Daily Summary Taxi Data (2017)", dataframe=daily_summary_2017)
# Out:
# Daily Summary Taxi Data (2017)
# <table id="itables_3790533b_8a6a_43e4_a97e_b7e354ce787d" class="display nowrap" data-quarto-disable-processing="true" style="table-layout:auto;width:auto;margin:auto;caption-side:bottom">
# <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>pickup_date</th>
#       <th>day of week</th>
#       <th>avg fares</th>
#       <th>total fares</th>
#       <th>tip percentage</th>
#       <th>duration</th>
#       <th>frequency_of_rides</th>
#       <th>avg trip distance</th>
#       <th>tip amount avg</th>
#       <th>avg passengers</th>
#       <th>sum of passengers</th>
#       <th>avg fare per mile</th>
#     </tr>
#   </thead><tbody><tr>
# <td style="vertical-align:middle; text-align:left">
# <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
# Loading ITables v2.2.4 from the internet...
# (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
# </tr></tbody>
# </table>
# <link href="https://www.unpkg.com/dt_for_itables@2.0.13/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import {DataTable, jQuery as $} from 'https://www.unpkg.com/dt_for_itables@2.0.13/dt_bundle.js';
#
#     document.querySelectorAll("#itables_
# %%
daily_summary = pd.concat([
    merged_daily_2014, 
    merged_daily_2015, 
    merged_daily_2016, 
    merged_daily_2017
], ignore_index=True)

daily_summary['pickup_date'] = pd.to_datetime(daily_summary['pickup_date'])
daily_summary = daily_summary.sort_values("pickup_date")

tools.display_dataframe_to_user(name="Daily Summary (2014-2017)", dataframe=daily_summary)
# Out:
# Daily Summary (2014-2017)
# <table id="itables_6b9b125d_265f_41c1_8abf_52c1ed29b94a" class="display nowrap" data-quarto-disable-processing="true" style="table-layout:auto;width:auto;margin:auto;caption-side:bottom">
# <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>pickup_date</th>
#       <th>day of week</th>
#       <th>avg fares</th>
#       <th>total fares</th>
#       <th>tip percentage</th>
#       <th>duration</th>
#       <th>frequency_of_rides</th>
#       <th>avg trip distance</th>
#       <th>tip amount avg</th>
#       <th>avg passengers</th>
#       <th>sum of passengers</th>
#       <th>avg fare per mile</th>
#       <th>Bronx_Pickups</th>
#       <th>Brooklyn_Pickups</th>
#       <th>EWR_Pickups</th>
#       <th>Manhattan_Pickups</th>
#       <th>Queens_Pickups</th>
#       <th>Staten Island_Pickups</th>
#       <th>Unknown_Pickups</th>
#       <th>Bronx_Dropoffs</th>
#       <th>Brooklyn_Dropoffs</th>
#       <th>EWR_Dropoffs</th>
#       <th>Manhattan_Dropoffs</th>
#       <th>Queens_Dropoffs</th>
#       <th>Staten Island_Dropoffs</th>
#       <th>Unknown_Dropoffs</th>
#     </tr>
#   </thead><tbody><tr>
# <td style="vertical-align:middle; text-align:left">
# <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
# Loading ITables v2.2.4 from the internet...
# (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
# </tr></tbody>
# </table>
# <link href="https://www.unpkg.com/dt_for_itables@2.0.13/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import {DataTable, jQuery as $} from 'https://www.unpkg.com/dt_for_itables@2.0.13/dt_bundle.js';
#
#     document.querySelectorAll("#itables_6b9b125d_265f_41c1_8abf_52c1ed29b94a:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         // Define the table data
#         const data = [[0, "2014-01-01", "Wednesday", 12.768159, 5293333.83, 9.496572, 11.313881, 414573, 3.346247, 1.212537, 1.830061, 758694, 5.136335, 939.0, 23633.0, 7.0, 359006.0, 26418.0, 9.0, 4374.0, 4245.0, 35266.0, 965.0, 338414.0, 30100.0, 138.0, 4366.0], [1, "2014-01-02", "Thursday", 11.628049, 4136004.1, 10.072117, 11.647123, 355692, 2.84441, 1.171191, 1.730874, 615658, 5.64309, 209.0, 5972.0, 8.0, 325354.0, 20081.0, 5.0, 3946.0, 1583.0, 13638.0, 877.0, 317491.0, 17601.0, 50.0, 3911.0], [2, "2014-01-03", "Friday", 11.814271, 3212938.24, 10.23399, 12.60555, 271954, 2.855969, 1.209071, 1.77847, 483662, 5.730146, 282.0, 6335.0, 7.0, 244618.0, 17624.0, 3.0, 2995.0, 1299.0, 13504.0, 596.0, 238808.0, 14169.0, 53.0, 2979.0], [3, "2014-01-04", "Saturday", 11.652071, 4814402.55, 10.425806, 11.983548, 413180, 2.791004, 1.214822, 1.788293, 738887, 5.685689, 220.0, 13031.0, 5.0, 374740.0, 20138.0, 19.0, 4904.0, 1959.0, 23841.0, 598.0, 362596.0, 18558.0, 76.0, 4894.0], [4, "2014-01-05", "Sunday", 12.124448, 4651653.41, 10.976544, 11.485255, 383659, 3.083875, 1.330845, 1.749986, 671398, 5.352977, 255.0, 13252.0, 6.0